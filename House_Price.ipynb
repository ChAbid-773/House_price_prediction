# %% [markdown]
# <a href="https://colab.research.google.com/github/ChAbid-773/House_price_prediction/blob/main/House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('content_drive')
# Out:
# Drive already mounted at content_drive; to attempt to forcibly remount, call drive.mount("content_drive", force_remount=True).

# %%
hp=pd.read_csv("content_drive/MyDrive/House_Price.csv")

# %%
hp
# Out:
#        Unnamed: 0 property_type     price             location       city  \
# 0               0          Flat  10000000                 G-10  Islamabad
# 1               1          Flat   6900000                 E-11  Islamabad
# 2               2         House  16500000                 G-15  Islamabad
# 3               3         House  43500000            Bani Gala  Islamabad
# 4               4         House   7000000          DHA Defence  Islamabad
# ...           ...           ...       ...                  ...        ...
# 99494      168435          Flat   7500000  Bahria Town Karachi    Karachi
# 99495      168436         House   8800000  Bahria Town Karachi    Karachi
# 99496      168438         House  14000000  Bahria Town Karachi    Karachi
# 99497      168439         House  14000000  Bahria Town Karachi    Karachi
# 99498      168445         House   9000000  Bahria Town Karachi    Karachi
#
#        baths   purpose  bedrooms  Area_in_Marla
# ...

# %%
hp.describe()
# Out:
#           Unnamed: 0         price         baths      bedrooms  Area_in_Marla
# count   99499.000000  9.949900e+04  99499.000000  99499.000000   99499.000000
# mean    78883.893064  1.037592e+07      3.530106      3.350737       8.757479
# std     48239.423663  1.066000e+07      1.474217      1.255913       7.466471
# min         0.000000  1.550000e+04      1.000000      0.000000       0.000000
# 25%     37236.500000  1.500000e+05      2.000000      2.000000       4.800000
# 50%     76065.000000  7.500000e+06      3.000000      3.000000       6.700000
# 75%    119401.500000  1.550000e+07      5.000000      4.000000      10.000000
# max    168445.000000  4.490000e+07      7.000000      6.000000     194.000000

# %%
hp.head(6)
# Out:
#    Unnamed: 0 property_type     price     location       city  baths  \
# 0           0          Flat  10000000         G-10  Islamabad      2
# 1           1          Flat   6900000         E-11  Islamabad      3
# 2           2         House  16500000         G-15  Islamabad      6
# 3           3         House  43500000    Bani Gala  Islamabad      4
# 4           4         House   7000000  DHA Defence  Islamabad      3
# 5           7          Flat   7800000         E-11  Islamabad      2
#
#     purpose  bedrooms  Area_in_Marla
# 0  For Sale         2            4.0
# 1  For Sale         3            5.6
# 2  For Sale         5            8.0
# 3  For Sale         4           40.0
# 4  For Sale         3            8.0
# 5  For Sale         2            6.2

# %%
hp.tail(6)
# Out:
#        Unnamed: 0 property_type     price             location     city  \
# 99493      168434          Flat   5200000  Bahria Town Karachi  Karachi
# 99494      168435          Flat   7500000  Bahria Town Karachi  Karachi
# 99495      168436         House   8800000  Bahria Town Karachi  Karachi
# 99496      168438         House  14000000  Bahria Town Karachi  Karachi
# 99497      168439         House  14000000  Bahria Town Karachi  Karachi
# 99498      168445         House   9000000  Bahria Town Karachi  Karachi
#
#        baths   purpose  bedrooms  Area_in_Marla
# 99493      2  For Sale         2            4.2
# 99494      3  For Sale         3            8.0
# 99495      4  For Sale         3            8.0
# 99496      3  For Sale         3            8.0
# 99497      4  For Sale         4           14.0
# 99498      3  For Sale         3            9.4

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99499 entries, 0 to 99498
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     99499 non-null  int64
#  1   property_type  99499 non-null  object
#  2   price          99499 non-null  int64
#  3   location       99499 non-null  object
#  4   city           99499 non-null  object
#  5   baths          99499 non-null  int64
#  6   purpose        99499 non-null  object
#  7   bedrooms       99499 non-null  int64
#  8   Area_in_Marla  99499 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 6.8+ MB

# %%
hp.value_counts()
# Out:
# Unnamed: 0  property_type  price     location             city       baths  purpose   bedrooms  Area_in_Marla
# 168445      House          9000000   Bahria Town Karachi  Karachi    3      For Sale  3         9.4              1
# 0           Flat           10000000  G-10                 Islamabad  2      For Sale  2         4.0              1
# 1           Flat           6900000   E-11                 Islamabad  3      For Sale  3         5.6              1
# 2           House          16500000  G-15                 Islamabad  6      For Sale  5         8.0              1
# 3           House          43500000  Bani Gala            Islamabad  4      For Sale  4         40.0             1
#                                                                                                                 ..
# 25          House          6800000   Koral Town           Islamabad  4      For Sale  4         4.0              1
# ...

# %%
hp['property_type'].value_counts()
# Out:
# property_type
# House            58169
# Flat             26658
# Upper Portion     8539
# Lower Portion     5549
# Penthouse          255
# Room               241
# Farm House          88
# Name: count, dtype: int64

# %%
hp.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
hp
# Out:
#       property_type     price             location       city  baths  \
# 0              Flat  10000000                 G-10  Islamabad      2
# 1              Flat   6900000                 E-11  Islamabad      3
# 2             House  16500000                 G-15  Islamabad      6
# 3             House  43500000            Bani Gala  Islamabad      4
# 4             House   7000000          DHA Defence  Islamabad      3
# ...             ...       ...                  ...        ...    ...
# 99494          Flat   7500000  Bahria Town Karachi    Karachi      3
# 99495         House   8800000  Bahria Town Karachi    Karachi      4
# 99496         House  14000000  Bahria Town Karachi    Karachi      3
# 99497         House  14000000  Bahria Town Karachi    Karachi      4
# 99498         House   9000000  Bahria Town Karachi    Karachi      3
#
#         purpose  bedrooms  Area_in_Marla
# 0      For Sale         2            4.0
# 1      For Sale         3            5.6
# ...

# %%
hp.value_counts()
# Out:
# property_type  price     location             city        baths  purpose   bedrooms  Area_in_Marla
# House          20000000  Bahria Town Karachi  Karachi     3      For Sale  3         8.0              179
#                42500000  DHA Defence          Lahore      6      For Sale  5         20.0             120
#                14000000  Bahria Town Karachi  Karachi     3      For Sale  3         8.0              103
#                13500000  Bahria Town Karachi  Karachi     3      For Sale  3         8.0              103
# Flat           6500000   Bahria Town Karachi  Karachi     2      For Sale  2         4.2               92
#                                                                                                      ...
# Farm House     200000    Chakri Road          Rawalpindi  4      For Rent  6         100.0              1
#                175000    G-10                 Islamabad   4      For Rent  6         142.0              1
# ...

# %%
hp.isnull()
# Out:
#        property_type  price  location   city  baths  purpose  bedrooms  \
# 0              False  False     False  False  False    False     False
# 1              False  False     False  False  False    False     False
# 2              False  False     False  False  False    False     False
# 3              False  False     False  False  False    False     False
# 4              False  False     False  False  False    False     False
# ...              ...    ...       ...    ...    ...      ...       ...
# 99494          False  False     False  False  False    False     False
# 99495          False  False     False  False  False    False     False
# 99496          False  False     False  False  False    False     False
# 99497          False  False     False  False  False    False     False
# 99498          False  False     False  False  False    False     False
#
#        Area_in_Marla
# 0              False
# 1              False
# 2              False
# 3              False
# ...

# %%
hp.fillna(2)
# Out:
#       property_type     price             location       city  baths  \
# 0              Flat  10000000                 G-10  Islamabad      2
# 1              Flat   6900000                 E-11  Islamabad      3
# 2             House  16500000                 G-15  Islamabad      6
# 3             House  43500000            Bani Gala  Islamabad      4
# 4             House   7000000          DHA Defence  Islamabad      3
# ...             ...       ...                  ...        ...    ...
# 99494          Flat   7500000  Bahria Town Karachi    Karachi      3
# 99495         House   8800000  Bahria Town Karachi    Karachi      4
# 99496         House  14000000  Bahria Town Karachi    Karachi      3
# 99497         House  14000000  Bahria Town Karachi    Karachi      4
# 99498         House   9000000  Bahria Town Karachi    Karachi      3
#
#         purpose  bedrooms  Area_in_Marla
# 0      For Sale         2            4.0
# 1      For Sale         3            5.6
# ...

# %%
hp['property_type'].value_counts()
# Out:
# property_type
# House            58169
# Flat             26658
# Upper Portion     8539
# Lower Portion     5549
# Penthouse          255
# Room               241
# Farm House          88
# Name: count, dtype: int64

# %%
hp['property_type']=hp['property_type'].replace({"House":1,"Flat":2,"Upper Portion":3,"Lower Portion":4,"Penthouse":5,"Room":6,"Farm House":7})
# Out:
# /tmp/ipykernel_17947/2057173835.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   hp['property_type']=hp['property_type'].replace({"House":1,"Flat":2,"Upper Portion":3,"Lower Portion":4,"Penthouse":5,"Room":6,"Farm House":7})

# %%
hp["property_type"].value_counts()
# Out:
# property_type
# 1    58169
# 2    26658
# 3     8539
# 4     5549
# 5      255
# 6      241
# 7       88
# Name: count, dtype: int64

# %%
hp['location'].value_counts()
# Out:
# location
# DHA Defence                 11787
# Bahria Town Karachi          6697
# Bahria Town Rawalpindi       5257
# Bahria Town                  4437
# Gulistan-e-Jauhar            3532
#                             ...
# Tulspura                        1
# Al-Hafeez Garden Road           1
# Airline Avenue                  1
# Sitara Supreme City             1
# Gulistan-e-Jinnah Colony        1
# Name: count, Length: 1389, dtype: int64

# %%
hp['location']=hp['location'].replace({"DHA Defence":1,"Bahria Town Karachi":2,"Bahria Town Rawalpindi":3,"Bahria Town":4,"Gulistan-e-Jauhar":5,"Tulspura":6,"Al-Hafeez Garden Road":7,"Airline Avenue":8,"Sitara Supreme City":9,"Gulistan-e-Jinnah Colony":10,"G-10":11,"E-11":12,"G-15":13,"Bani Gala":14})

# %%
hp['location'].value_counts()
# Out:
# location
# 1     11787
# 2      6697
# 3      5257
# 4      4437
# 5      3532
#       ...
# 6         1
# 7         1
# 8         1
# 9         1
# 10        1
# Name: count, Length: 1389, dtype: int64

# %%
hp
# Out:
#        property_type     price location       city  baths   purpose  bedrooms  \
# 0                  2  10000000       11  Islamabad      2  For Sale         2
# 1                  2   6900000       12  Islamabad      3  For Sale         3
# 2                  1  16500000       13  Islamabad      6  For Sale         5
# 3                  1  43500000       14  Islamabad      4  For Sale         4
# 4                  1   7000000        1  Islamabad      3  For Sale         3
# ...              ...       ...      ...        ...    ...       ...       ...
# 99494              2   7500000        2    Karachi      3  For Sale         3
# 99495              1   8800000        2    Karachi      4  For Sale         3
# 99496              1  14000000        2    Karachi      3  For Sale         3
# 99497              1  14000000        2    Karachi      4  For Sale         4
# 99498              1   9000000        2    Karachi      3  For Sale         3
#
#        Area_in_Marla
# ...

# %%
from sklearn.preprocessing import LabelEncoder
coder=LabelEncoder()

# %%
obj_cols = hp.select_dtypes(include=['object']).columns
print(f'Converting columns: {list(obj_cols)}')

for col in obj_cols:
    hp[col] = coder.fit_transform(hp[col].astype(str))

hp['Area_in_Marla'] = hp['Area_in_Marla'].astype(int)

display(hp.info())
# Out:
# Converting columns: ['location', 'city', 'purpose']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99499 entries, 0 to 99498
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  99499 non-null  int64
#  1   price          99499 non-null  int64
#  2   location       99499 non-null  int64
#  3   city           99499 non-null  int64
#  4   baths          99499 non-null  int64
#  5   purpose        99499 non-null  int64
#  6   bedrooms       99499 non-null  int64
#  7   Area_in_Marla  99499 non-null  int64
# dtypes: int64(8)
# memory usage: 6.1 MB
# None

# %%
hp["city"].value_counts()
# Out:
# city
# 2    37066
# 3    26221
# 1    22243
# 4    11738
# 0     2231
# Name: count, dtype: int64

# %%
x=hp.drop('price',axis=1)
y=hp['price']

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# #**Matplotlib Plot**

# %%
plt.plot(hp['property_type'], hp['Area_in_Marla'])
plt.title('Line')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
# Out:
# Text(0, 0.5, 'Area_in_Marla')

# %%
plt.scatter(hp['property_type'], hp['Area_in_Marla'])
plt.title('Pair')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
# Out:
# Text(0, 0.5, 'Area_in_Marla')

# %%
plt.hist(hp['Area_in_Marla'])
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
plt.boxplot(hp['Area_in_Marla'])
plt.title('Box')
# Out:
# Text(0.5, 1.0, 'Box')

# %%
plt.violinplot(hp['Area_in_Marla'])
plt.title('Violin')
# Out:
# Text(0.5, 1.0, 'Violin')

# %%
hp['Area_in_Marla'].plot(kind="kde")
plt.title('KDE')
# Out:
# Text(0.5, 1.0, 'KDE')

# %% [markdown]
# #**Seaborn Plot**

# %%
sns.scatterplot(x=hp['property_type'], y=hp['Area_in_Marla'])
plt.title('Scatter')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
plt.show()

# %%
sns.lineplot(x=hp['property_type'], y=hp['Area_in_Marla'])
plt.title('Line')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
plt.show()

# %%
sns.barplot(x=hp['property_type'], y=hp['Area_in_Marla'])
plt.title('Bar')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
plt.show()

# %%
sns.boxplot(x=hp['property_type'], y=hp['Area_in_Marla'])
plt.title('Box')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
plt.show()

# %%
sns.violinplot(x=hp['property_type'], y=hp['Area_in_Marla'])
plt.title('Violin')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
plt.show()

# %%
sns.pairplot(hp[['property_type', 'Area_in_Marla']])
plt.title('Pair')
plt.xlabel('property_type')
plt.ylabel('Area_in_Marla')
plt.show()

# %%
sns.histplot(hp['Area_in_Marla'])
plt.title('HistoGram')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79599 entries, 2489 to 89755
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  79599 non-null  int64
#  1   location       79599 non-null  int64
#  2   city           79599 non-null  int64
#  3   baths          79599 non-null  int64
#  4   purpose        79599 non-null  int64
#  5   bedrooms       79599 non-null  int64
#  6   Area_in_Marla  79599 non-null  int64
# dtypes: int64(7)
# memory usage: 4.9 MB

# %% [markdown]
# #**Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x_train,y_train)
y_pred1=model1.predict(x_test)
print(y_pred1)
# Out:
# [-2658858.97298443 24484096.61687695 12190266.41712062 ...
#  22704972.46302389  8927939.7419011  -2345712.91868301]

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred1}).reset_index(drop=True)
df1
# Out:
#          Actual     Predicted
# 0         45000 -2.658859e+06
# 1      39500000  2.448410e+07
# 2       8242000  1.219027e+07
# 3         48000  7.801749e+05
# 4      34000000  2.443393e+07
# ...         ...           ...
# 19895     40000 -5.186429e+06
# 19896    325000  1.046262e+07
# 19897  33500000  2.270497e+07
# 19898   4200000  8.927940e+06
# 19899     40000 -2.345713e+06
#
# [19900 rows x 2 columns]

# %%
model1.predict([[1,2,3,1,3,4,4]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([39714122.29001249])

# %% [markdown]
# #**K Means**

# %%
from sklearn.cluster import KMeans
model3=KMeans(n_clusters=3)
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)
print(y_pred3)
# Out:
# [2 0 2 ... 0 1 0]

# %%
df3=pd.DataFrame({'Actual':y_test,'Predicted':y_pred3}).reset_index(drop=True)
df3
# Out:
#          Actual  Predicted
# 0         45000          2
# 1      39500000          0
# 2       8242000          2
# 3         48000          0
# 4      34000000          2
# ...         ...        ...
# 19895     40000          2
# 19896    325000          0
# 19897  33500000          0
# 19898   4200000          1
# 19899     40000          0
#
# [19900 rows x 2 columns]

# %%
model3.predict([[1,2,3,1,3,4,4]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([0], dtype=int32)

# %% [markdown]
# #**Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
model4=DecisionTreeClassifier()
model4.fit(x_train,y_train)
y_pred4=model4.predict(x_test)
print(y_pred4)
# Out:
# [   50000 42500000  8242000 ... 35000000  3250000    40000]

# %%
df4=pd.DataFrame({'Actual':y_test,'Predicted':y_pred4}).reset_index(drop=True)
df4
# Out:
#          Actual  Predicted
# 0         45000      50000
# 1      39500000   42500000
# 2       8242000    8242000
# 3         48000      45000
# 4      34000000   36500000
# ...         ...        ...
# 19895     40000      25000
# 19896    325000     375000
# 19897  33500000   35000000
# 19898   4200000    3250000
# 19899     40000      40000
#
# [19900 rows x 2 columns]

# %%
model4.predict([[1,2,3,1,3,4,4]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([33000000])
